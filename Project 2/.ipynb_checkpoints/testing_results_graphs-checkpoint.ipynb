# %% [markdown]
# ### Bot 1 vs Bot 2, as a function of k
#
# #### k values: [1, 2, 3, 4, 5]

# %%
import matplotlib.pyplot as plt

# Hyperparameter values
k_values = [1, 2, 3, 4, 5]

bot1_data = [1078.4, 631.3, 559.7, 389, 357.9]
bot2_data = [1334.8, 846.7, 374.8, 299.4, 212.5]
# bot3_data = [1.00, 0.96, 0.93, 0.91, 0.88]
# bot4_data = [1.00, 0.95, 0.94, 0.92, 0.91]


plt.figure(figsize=(10, 6))
plt.plot(q_values, bot1_data, marker='o', label='Bot 1')
plt.plot(q_values, bot2_data, marker='o', label='Bot 2')
# plt.plot(q_values, bot3_data, marker='o', label='Bot 3')
# plt.plot(q_values, bot4_data, marker='o', label='Bot 4')

plt.xticks(q_values)

plt.title('Success Rate of Bots vs. q values (100 Experiments, ship_size=20)')
plt.xlabel('k value')
plt.ylabel('Average Action')
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()

# Display the plot
plt.show()

# %%
50x50 grids

# %%
import matplotlib.pyplot as plt

# Hyperparameter values
q_values = [0, 0.25, 0.5, 0.75, 1]

bot1_data = [0.98, 0.92, 0.85, 0.82, 0.75]
bot2_data = [1.0, 0.98, 0.94, 0.85, 0.82]
bot3_data = [1.0, 0.97, 0.94, 0.92, 0.89]
bot4_data = [1.0, 0.95, 0.95, 0.93, 0.92]
plt.figure(figsize=(10, 6))
plt.plot(q_values, bot1_data, marker='o', label='Bot 1')
plt.plot(q_values, bot2_data, marker='o', label='Bot 2')
plt.plot(q_values, bot3_data, marker='o', label='Bot 3')
plt.plot(q_values, bot4_data, marker='o', label='Bot 4')

plt.xticks(q_values)

plt.title('Success Rate of Bots vs. q values (100 Experiments, ship_size=50)')
plt.xlabel('q value')
plt.ylabel('Success Rate')
plt.legend()
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.tight_layout()

# Display the plot
plt.show()
